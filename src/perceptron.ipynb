# %% [markdown]
# # O Preceptron funciona?
#
# Veja o vídeo que foi apresentado em sala de aula e vamos tentar reproduzir a proposta dos criadores do _perceptron_. Tentaremos treinar o mesmo para distinguir entre quadrados e círculos. Vamos alimentar o algoritmo de treino com 600 imagens de 20 por 20 pixels. Teremos 300 imagens de retângulos e 300 de círculos; Vamos criar mais 50 imagens de cada classe para teste.
#
# Vamos criar as imagens.

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
listaImagens = []
# Criando 350 retângulos
for i in range(350):
    rect = np.zeros((20, 20))
    lA = np.random.randint(3, 20)
    lB = np.random.randint(3, 20)
    px = np.random.randint(0, 20-lA)
    py = np.random.randint(0, 20-lB)
    rect[px:px+lA, py:py+lB] = 1
    listaImagens.append(rect)

# Criando 350 círculos
for i in range(350):
    circle = np.zeros((20, 20))
    radius = np.random.randint(2, 10)
    cx = np.random.randint(radius, 20-radius)
    cy = np.random.randint(radius, 20-radius)
    for x in range(20):
        for y in range(20):
            if (x-cx)**2 + (y-cy)**2 <= radius**2:
                circle[x, y] = 1
    listaImagens.append(circle)

# %%
from matplotlib import pyplot as plt
#%matplotlib widget

# %%
fig, ax = plt.subplots(10, 10)
for i in range(10):
    for j in range(10):
        ax[i, j].imshow(listaImagens[i*5+j], cmap='gray')
        ax[i, j].axis('off')

# %%
fig, ax = plt.subplots(10, 10)
for i in range(10):
    for j in range(10):
        ax[i, j].imshow(listaImagens[350 + i*5 + j], cmap='gray')
        ax[i, j].axis('off')

# %%
listaTreino = [(img, 0) for img in listaImagens[:300]] + [(img, 1) for img in listaImagens[350:650]]
listaTeste = [(img, 0) for img in listaImagens[300:350]] + [(img, 1) for img in listaImagens[650:]]

# %%
import random
random.shuffle(listaTreino)
print(type(listaTreino))
# Out:
# <class 'list'>

# %%
percep = np.zeros((20,20))
bias = 0
fig, ax = plt.subplots(5, 5)
for epoch in range(1,201):
    accuracy = 0
    for img, label in listaTreino:
        y = np.sum(img*percep)
        y = 1 if y > bias else 0
        percep += (label - y)*img
        accuracy += int(label == y)
    accuracy /= len(listaTreino)
    print(f'Epoch {epoch}: accuracy = {accuracy}')
    if ((epoch  % 8) == 0):
        j = ((epoch  % 40) // 8) - 1
        i = (epoch - 1) // 40  
        ax[i, j].imshow(percep, cmap = plt.cm.viridis)
        ax[i, j].axis('off')
    if accuracy == 1:
        break
# Out:
# Epoch 1: accuracy = 0.585
# Epoch 2: accuracy = 0.64
# Epoch 3: accuracy = 0.6566666666666666
# Epoch 4: accuracy = 0.66
# Epoch 5: accuracy = 0.7016666666666667
# Epoch 6: accuracy = 0.7083333333333334
# Epoch 7: accuracy = 0.7066666666666667
# Epoch 8: accuracy = 0.7283333333333334
# Epoch 9: accuracy = 0.7516666666666667
# Epoch 10: accuracy = 0.7283333333333334
# Epoch 11: accuracy = 0.7266666666666667
# Epoch 12: accuracy = 0.7683333333333333
# Epoch 13: accuracy = 0.77
# Epoch 14: accuracy = 0.7783333333333333
# Epoch 15: accuracy = 0.7666666666666667
# Epoch 16: accuracy = 0.7666666666666667
# Epoch 17: accuracy = 0.7983333333333333
# Epoch 18: accuracy = 0.79
# Epoch 19: accuracy = 0.8183333333333334
# Epoch 20: accuracy = 0.8083333333333333
# Epoch 21: accuracy = 0.785
# Epoch 22: accuracy = 0.7883333333333333
# Epoch 23: accuracy = 0.8083333333333333
# Epoch 24: accuracy = 0.8333333333333334
# Epoch 25: accuracy = 0.8266666666666667
# Epoch 26: accuracy = 0.7916666666666666
# Epoch 27: accuracy = 0.8183333333333334
# Epoch 28: accuracy = 0.8283333333333334
# Epoch 29: accuracy = 0.84
# Epoch 30: accuracy = 0.8066666666666666
# Epoch 31: accuracy = 0.85
# Epoch 32: accuracy = 0.8333333333333334
# Epoch 33: accuracy = 0.8366666666666667
# Epoch 34: accuracy = 0.825
# Epoch 35: accuracy = 0.8416666666666667
# Epoch 36: accuracy = 0.8616666666666667
# Epoch 37: accuracy = 0.83
# Epoch 38: accuracy = 0.8533333333333334
# Epoch 39: accuracy = 0.86
# Epoch 40: accuracy = 0.87
# Epoch 41: accuracy = 0.8683333333333333
# Epoch 42: accuracy = 0.8733333333333333
# Epoch 43: accuracy = 0.8683333333333333
# Epoch 44: accuracy = 0.8783333333333333
# Epoch 45: accuracy = 0.875
# Epoch 46: accuracy = 0.8933333333333333
# Epoch 47: accuracy = 0.89
# Epoch 48: accuracy = 0.8983333333333333
# Epoch 49: accuracy = 0.9
# Epoch 50: accuracy = 0.8533333333333334
# Epoch 51: accuracy = 0.87
# Epoch 52: accuracy = 0.8883333333333333
# Epoch 53: accuracy = 0.8716666666666667
# Epoch 54: accuracy = 0.865
# Epoch 55: accuracy = 0.875
# Epoch 56: accuracy = 0.8733333333333333
# Epoch 57: accuracy = 0.8683333333333333
# Epoch 58: accuracy = 0.8833333333333333
# Epoch 59: accuracy = 0.8933333333333333
# Epoch 60: accuracy = 0.8933333333333333
# Epoch 61: accuracy = 0.9033333333333333
# Epoch 62: accuracy = 0.8766666666666667
# Epoch 63: accuracy = 0.895
# Epoch 64: accuracy = 0.92
# Epoch 65: accuracy = 0.915
# Epoch 66: accuracy = 0.9
# Epoch 67: accuracy = 0.895
# Epoch 68: accuracy = 0.92
# Epoch 69: accuracy = 0.8866666666666667
# Epoch 70: accuracy = 0.895
# Epoch 71: accuracy = 0.905
# Epoch 72: accuracy = 0.9033333333333333
# Epoch 73: accuracy = 0.9066666666666666
# Epoch 74: accuracy = 0.9066666666666666
# Epoch 75: accuracy = 0.94
# Epoch 76: accuracy = 0.9
# Epoch 77: accuracy = 0.915
# Epoch 78: accuracy = 0.9016666666666666
# Epoch 79: accuracy = 0.94
# Epoch 80: accuracy = 0.9366666666666666
# Epoch 81: accuracy = 0.91
# Epoch 82: accuracy = 0.935
# Epoch 83: accuracy = 0.9166666666666666
# Epoch 84: accuracy = 0.9433333333333334
# Epoch 85: accuracy = 0.915
# Epoch 86: accuracy = 0.9266666666666666
# Epoch 87: accuracy = 0.905
# Epoch 88: accuracy = 0.9283333333333333
# Epoch 89: accuracy = 0.9316666666666666
# Epoch 90: accuracy = 0.9183333333333333
# Epoch 91: accuracy = 0.9116666666666666
# Epoch 92: accuracy = 0.9433333333333334
# Epoch 93: accuracy = 0.9516666666666667
# Epoch 94: accuracy = 0.935
# Epoch 95: accuracy = 0.9333333333333333
# Epoch 96: accuracy = 0.9433333333333334
# Epoch 97: accuracy = 0.95
# Epoch 98: accuracy = 0.94
# Epoch 99: accuracy = 0.955
# Epoch 100: accuracy = 0.9383333333333334
# Epoch 101: accuracy = 0.93
# Epoch 102: accuracy = 0.93
# Epoch 103: accuracy = 0.9183333333333333
# Epoch 104: accuracy = 0.9266666666666666
# Epoch 105: accuracy = 0.9333333333333333
# Epoch 106: accuracy = 0.9283333333333333
# Epoch 107: accuracy = 0.935
# Epoch 108: accuracy = 0.9533333333333334
# Epoch 109: accuracy = 0.9566666666666667
# Epoch 110: accuracy = 0.9483333333333334
# Epoch 111: accuracy = 0.9716666666666667
# Epoch 112: accuracy = 0.9566666666666667
# Epoch 113: accuracy = 0.9516666666666667
# Epoch 114: accuracy = 0.9466666666666667
# Epoch 115: accuracy = 0.9633333333333334
# Epoch 116: accuracy = 0.9583333333333334
# Epoch 117: accuracy = 0.9533333333333334
# Epoch 118: accuracy = 0.935
# Epoch 119: accuracy = 0.9416666666666667
# Epoch 120: accuracy = 0.9316666666666666
# Epoch 121: accuracy = 0.9466666666666667
# Epoch 122: accuracy = 0.9466666666666667
# Epoch 123: accuracy = 0.9333333333333333
# Epoch 124: accuracy = 0.9383333333333334
# Epoch 125: accuracy = 0.9633333333333334
# Epoch 126: accuracy = 0.965
# Epoch 127: accuracy = 0.9683333333333334
# Epoch 128: accuracy = 0.9616666666666667
# Epoch 129: accuracy = 0.9716666666666667
# Epoch 130: accuracy = 0.9666666666666667
# Epoch 131: accuracy = 0.9583333333333334
# Epoch 132: accuracy = 0.9633333333333334
# Epoch 133: accuracy = 0.9883333333333333
# Epoch 134: accuracy = 0.9616666666666667
# Epoch 135: accuracy = 0.96
# Epoch 136: accuracy = 0.9783333333333334
# Epoch 137: accuracy = 0.95
# Epoch 138: accuracy = 0.955
# Epoch 139: accuracy = 0.97
# Epoch 140: accuracy = 0.9716666666666667
# Epoch 141: accuracy = 0.9716666666666667
# Epoch 142: accuracy = 0.97
# Epoch 143: accuracy = 0.955
# Epoch 144: accuracy = 0.9683333333333334
# Epoch 145: accuracy = 0.98
# Epoch 146: accuracy = 0.9733333333333334
# Epoch 147: accuracy = 0.97
# Epoch 148: accuracy = 0.9533333333333334
# Epoch 149: accuracy = 0.9733333333333334
# Epoch 150: accuracy = 0.97
# Epoch 151: accuracy = 0.9816666666666667
# Epoch 152: accuracy = 0.9833333333333333
# Epoch 153: accuracy = 0.98
# Epoch 154: accuracy = 0.9783333333333334
# Epoch 155: accuracy = 0.9933333333333333
# Epoch 156: accuracy = 0.9566666666666667
# Epoch 157: accuracy = 0.9816666666666667
# Epoch 158: accuracy = 1.0

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(percep, cmap = plt.cm.viridis)
ax.axis('off')
# Out:
# (-0.5, 19.5, 19.5, -0.5)

# %%
accuracy = 0
for img, label in listaTeste:
    y = np.sum(img*percep)
    y = 1 if y > bias else 0
    print(f'Label = {label}, y = {y}') 
    accuracy += int(label == y)
accuracy /= len(listaTeste)
print(f'Accuracy = {accuracy}')
# Out:
# Label = 0, y = 1
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 1
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 0, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 0
# Label = 1, y = 0
# Label = 1, y = 0
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 0
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Label = 1, y = 1
# Accuracy = 0.71

# %% [markdown]
# Vamos ver na prática como funciona o perceptron.

# %%
img = listaImagens[random.randint(0, 699)]
fig, ax = plt.subplots(1, 1)
ax.imshow(img, cmap='gray')
ax.axis('off')
# Out:
# (-0.5, 19.5, 19.5, -0.5)

# %%
isCircle = np.sum(img*percep)
isCircle = True if isCircle > bias else False
print(f'Output = {isCircle}')
# Out:
# Output = True
